# %%
#load in our libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import set_config
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
#output dataframes instead of arrays
set_config(transform_output="pandas")

# %%
#load in our dataset 
sacramento = pd.read_csv("dataset/sacramento.csv")
sacramento
# Out:
#                     street        city    zip state  beds  baths  sq__ft  \
# 0          1005 MORENO WAY  SACRAMENTO  95838    CA     3      2    1410
# 1     10105 MONTE VALLO CT  SACRAMENTO  95827    CA     4      2    1578
# 2        10133 NEBBIOLO CT   ELK GROVE  95624    CA     4      3    2096
# 3         10165 LOFTON WAY   ELK GROVE  95757    CA     3      2    1540
# 4        10254 JULIANA WAY  SACRAMENTO  95827    CA     4      2    2484
# ..                     ...         ...    ...   ...   ...    ...     ...
# 808     9507 SEA CLIFF WAY   ELK GROVE  95758    CA     4      2    2056
# 809  9570 HARVEST ROSE WAY  SACRAMENTO  95827    CA     5      3    2367
# 810       9723 TERRAPIN CT   ELK GROVE  95757    CA     4      3    2354
# 811   9837 CORTE DORADO CT   ELK GROVE  95624    CA     4      2    1616
# 812          9861 CULP WAY  SACRAMENTO  95827    CA     4      2    1380
#
#             type                     sale_date   price   latitude   longitude
# 0    Residential  Fri May 16 00:00:00 EDT 2008  180000  38.646206 -121.442767
# 1    Residential  Fri May 16 00:00:00 EDT 2008  190000  38.573917 -121.316916
# 2    Residential  Fri May 16 00:00:00 EDT 2008  289000  38.391085 -121.347231
# 3    Residential  Fri May 16 00:00:00 EDT 2008  266510  38.387708 -121.436522
# 4    Residential  Fri May 16 00:00:00 EDT 2008  331200  38.568030 -121.309966
# ..           ...                           ...     ...        ...         ...
# 808  Residential  Wed May 21 00:00:00 EDT 2008  285000  38.410992 -121.479043
# 809  Residential  Wed May 21 00:00:00 EDT 2008  315537  38.555993 -121.340352
# 810  Residential  Wed May 21 00:00:00 EDT 2008  335750  38.403492 -121.430224
# 811  Residential  Wed May 21 00:00:00 EDT 2008  227887  38.400676 -121.381010
# 812  Residential  Wed May 21 00:00:00 EDT 2008  131200  38.558423 -121.327948
#
# [813 rows x 12 columns]

# %%
# Plot
plt.scatter(sacramento["sq__ft"], sacramento['price'])

# Add labels and legend
plt.xlabel("House size (square feet)")
plt.ylabel('Price (USD)')
plt.title('Scatter Plot of House size vs Price')
plt.show()

# %%
np.random.seed(10)
small_sacramento = sacramento.sample(n = 30)
small_sacramento
# Out:
#                     street             city    zip state  beds  baths  sq__ft  \
# 486       7540 HICKORY AVE       ORANGEVALE  95662    CA     3      1    1456
# 399         9013 CASALS ST       SACRAMENTO  95826    CA     2      1     795
# 233       12901 FURLONG DR           WILTON  95693    CA     5      3    3788
# 408   9474 VILLAGE TREE DR        ELK GROVE  95758    CA     4      2    1776
# 549       2901 PINTAIL WAY        ELK GROVE  95757    CA     4      3    3070
# 43        191 BARNHART CIR       SACRAMENTO  95835    CA     4      2    2605
# 181        8316 NORTHAM DR         ANTELOPE  95843    CA     3      2    1235
# 250    2130 CATHERWOOD WAY       SACRAMENTO  95835    CA     3      2    1424
# 140         620 KESWICK CT      GRANITE BAY  95746    CA     4      3    2356
# 392        8593 DERLIN WAY       SACRAMENTO  95823    CA     3      2    1436
# 770     7223 KALLIE KAY LN       SACRAMENTO  95823    CA     3      2    1463
# 280              3228 I ST       SACRAMENTO  95816    CA     4      3    1939
# 448         5136 CABOT CIR       SACRAMENTO  95820    CA     4      2    1462
# 546      241 LANFRANCO CIR       SACRAMENTO  95835    CA     4      4    3397
# 27           1455 64TH AVE       SACRAMENTO  95822    CA     3      2    1169
# 550        2981 WRINGER DR        ROSEVILLE  95661    CA     4      3    3838
# 628  7140 BLUE SPRINGS WAY   CITRUS HEIGHTS  95621    CA     3      2    1156
# 197     8986 HAFLINGER WAY        ELK GROVE  95757    CA     3      2    1857
# 491    7809 VALLECITOS WAY       SACRAMENTO  95828    CA     3      1     888
# 786      8025 PEERLESS AVE       ORANGEVALE  95662    CA     2      1    1690
# 743  5579 JERRY LITELL WAY       SACRAMENTO  95835    CA     5      3    3599
# 511           87 LACAM CIR       SACRAMENTO  95820    CA     2      2    1188
# 163       7577 EDDYLEE WAY       SACRAMENTO  95822    CA     4      2    1436
# 325  5201 BLOSSOM RANCH DR        ELK GROVE  95757    CA     4      4    4303
# 415       1140 EDMONTON DR       SACRAMENTO  95833    CA     3      2    1204
# 599          5340 BIRK WAY       SACRAMENTO  95835    CA     3      2    1776
# 131        5805 DOTMAR WAY  NORTH HIGHLANDS  95660    CA     2      1     904
# 293          3662 RIVER DR       SACRAMENTO  95833    CA     4      3    2447
# 52            2327 32ND ST       SACRAMENTO  95817    CA     2      1    1115
# 661     9629 CEDAR OAK WAY        ELK GROVE  95757    CA     5      4    3260
#
#             type                     sale_date   price   latitude   longitude
# 486  Residential  Thu May 15 00:00:00 EDT 2008  225000  38.703056 -121.235221
# 399        Condo  Mon May 19 00:00:00 EDT 2008  126960  38.557045 -121.371670
# 233  Residential  Mon May 19 00:00:00 EDT 2008  691659  38.413535 -121.188211
# 408  Residential  Mon May 19 00:00:00 EDT 2008  210000  38.413947 -121.408276
# 549  Residential  Tue May 20 00:00:00 EDT 2008  495000  38.398488 -121.473424
# 43   Residential  Fri May 16 00:00:00 EDT 2008  257200  38.675594 -121.515878
# 181  Residential  Fri May 16 00:00:00 EDT 2008  246544  38.720767 -121.376678
# 250  Residential  Mon May 19 00:00:00 EDT 2008  251000  38.675506 -121.510987
# 140  Residential  Fri May 16 00:00:00 EDT 2008  600000  38.732096 -121.219142
# 392  Residential  Mon May 19 00:00:00 EDT 2008  180000  38.447585 -121.426627
# 770  Residential  Wed May 21 00:00:00 EDT 2008  174250  38.477553 -121.419463
# 280  Residential  Mon May 19 00:00:00 EDT 2008  215000  38.573844 -121.462839
# 448  Residential  Thu May 15 00:00:00 EDT 2008  121500  38.528479 -121.411806
# 546  Residential  Tue May 20 00:00:00 EDT 2008  465000  38.665696 -121.549437
# 27   Residential  Fri May 16 00:00:00 EDT 2008  122000  38.492177 -121.503392
# 550  Residential  Tue May 20 00:00:00 EDT 2008  613401  38.735373 -121.227072
# 628  Residential  Tue May 20 00:00:00 EDT 2008  161653  38.720653 -121.302241
# 197  Residential  Fri May 16 00:00:00 EDT 2008  285000  38.397923 -121.450219
# 491  Residential  Thu May 15 00:00:00 EDT 2008  216021  38.508217 -121.411207
# 786  Residential  Wed May 21 00:00:00 EDT 2008  334150  38.711470 -121.216214
# 743  Residential  Wed May 21 00:00:00 EDT 2008  381300  38.677126 -121.500519
# 511  Residential  Thu May 15 00:00:00 EDT 2008  123675  38.532359 -121.411670
# 163  Residential  Fri May 16 00:00:00 EDT 2008  185074  38.482910 -121.491509
# 325  Residential  Mon May 19 00:00:00 EDT 2008  450000  38.399436 -121.444041
# 415  Residential  Thu May 15 00:00:00 EDT 2008  174250  38.624570 -121.486913
# 599  Residential  Tue May 20 00:00:00 EDT 2008  234000  38.672495 -121.515251
# 131  Residential  Fri May 16 00:00:00 EDT 2008   63000  38.672642 -121.380343
# 293  Residential  Mon May 19 00:00:00 EDT 2008  246000  38.604969 -121.542550
# 52   Residential  Fri May 16 00:00:00 EDT 2008  220000  38.557433 -121.470340
# 661  Residential  Tue May 20 00:00:00 EDT 2008  385000  38.405527 -121.431746

# %%
# Plot
plt.scatter(small_sacramento["sq__ft"], small_sacramento['price'])

# Add a vertical line at 2,000 square feet
plt.axvline(x=2000, color='red', linestyle='--', label='2000 sqft')

# Add labels and legend
plt.xlabel("House size (square feet)")
plt.ylabel('Price (USD)')
plt.title('Scatter Plot of House size vs Price')

plt.show()

# %%
#calculate the abs difference betweeen 2000 and each house in our data
small_sacramento["dist"] = (2000 - small_sacramento["sq__ft"]).abs()

# %%
#find the rows with the smallest distance 
nearest_neighbors = small_sacramento.nsmallest(5, "dist")

# %%
# Scatter plot
plt.scatter(small_sacramento["sq__ft"], small_sacramento['price'], label='All houses')

# Plot nearest neighbors in orange
plt.scatter(nearest_neighbors["sq__ft"], nearest_neighbors['price'], color='orange', label='Nearest neighbors', edgecolor='black')

# Add a vertical line at 2,000 square feet
plt.axvline(x=2000, color='red', linestyle='--', label='2000 sqft')

# Add labels, title, and legend
plt.xlabel("House size (square feet)")
plt.ylabel('Price (USD)')
plt.title('Scatter Plot of House Size vs Price')
plt.legend()

# %%
nearest_neighbors["price"].mean()
# Out:
# np.float64(255630.0)

# %%
#splitting our data into training and testing
sacramento_train, sacramento_test = train_test_split(sacramento, train_size= 0.75, random_state= 42)

# %%
#step 1. define our X and y 
X_train = sacramento_train[["sq__ft"]]
y_train = sacramento_train["price"]

# %%
#step 2. initialize our KNN regressor
knn_regressor = KNeighborsRegressor()

# %%
#step 3. define our parameter grid 
param_grid = {
    "n_neighbors" : range(1,201,3)
}

# %%
#step 4. intialize our grid search
sacr_gridsearch = GridSearchCV(
    estimator= knn_regressor,
    param_grid=param_grid,
    cv = 5,
    scoring = "neg_root_mean_squared_error" #r2
)

# %%
#step 5. fit our grid search to the training data
sacr_gridsearch.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(1, 201, 3)},
#              scoring='neg_root_mean_squared_error')

# %%
pd.set_option('display.max_rows', None)

results = pd.DataFrame(sacr_gridsearch.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002194      0.002368         0.002213        0.001087
# 1        0.001453      0.000663         0.001558        0.000346
# 2        0.001429      0.000297         0.001576        0.000440
# 3        0.001258      0.000485         0.001502        0.000429
# 4        0.000739      0.000167         0.000823        0.000074
# 5        0.000627      0.000045         0.000769        0.000063
# 6        0.000753      0.000129         0.001094        0.000153
# 7        0.000662      0.000200         0.001171        0.000455
# 8        0.000671      0.000150         0.000878        0.000238
# 9        0.000674      0.000102         0.000891        0.000072
# 10       0.000693      0.000198         0.000857        0.000064
# 11       0.000578      0.000017         0.001048        0.000231
# 12       0.000662      0.000079         0.001328        0.000647
# 13       0.000658      0.000071         0.001150        0.000227
# 14       0.000711      0.000197         0.001012        0.000166
# 15       0.000592      0.000059         0.001038        0.000177
# 16       0.000816      0.000484         0.001084        0.000196
# 17       0.000650      0.000047         0.001313        0.000165
# 18       0.000701      0.000177         0.001494        0.000413
# 19       0.000728      0.000098         0.001272        0.000267
# 20       0.000783      0.000205         0.001602        0.000383
# 21       0.000953      0.000325         0.001522        0.000480
# 22       0.000929      0.000260         0.001634        0.000467
# 23       0.000943      0.000336         0.001429        0.000255
# 24       0.000839      0.000332         0.001445        0.000250
# 25       0.000706      0.000203         0.001498        0.000217
# 26       0.000983      0.000471         0.001411        0.000169
# 27       0.000800      0.000218         0.001595        0.000292
# 28       0.000828      0.000306         0.001682        0.000505
# 29       0.000709      0.000112         0.001621        0.000191
# 30       0.000819      0.000186         0.001695        0.000252
# 31       0.000726      0.000187         0.001906        0.000388
# 32       0.000788      0.000242         0.001921        0.000231
# 33       0.000697      0.000075         0.001510        0.000113
# 34       0.000712      0.000069         0.001747        0.000255
# 35       0.000672      0.000044         0.001679        0.000175
# 36       0.000656      0.000026         0.001681        0.000122
# 37       0.000646      0.000038         0.001674        0.000102
# 38       0.000822      0.000301         0.001729        0.000209
# 39       0.000622      0.000032         0.001670        0.000166
# 40       0.000659      0.000031         0.001846        0.000160
# 41       0.000707      0.000159         0.001748        0.000192
# 42       0.000625      0.000030         0.001771        0.000176
# 43       0.000707      0.000128         0.001780        0.000086
# 44       0.000631      0.000034         0.001805        0.000077
# 45       0.000720      0.000065         0.001896        0.000056
# 46       0.000638      0.000027         0.002006        0.000290
# 47       0.000654      0.000032         0.002020        0.000277
# 48       0.000709      0.000066         0.001946        0.000152
# 49       0.000750      0.000118         0.002013        0.000240
# 50       0.000697      0.000067         0.001966        0.000076
# 51       0.000734      0.000112         0.002083        0.000067
# 52       0.000868      0.000255         0.002213        0.000233
# 53       0.000893      0.000387         0.002176        0.000220
# 54       0.000867      0.000339         0.002413        0.000268
# 55       0.000722      0.000019         0.002488        0.000120
# 56       0.000728      0.000027         0.002601        0.000128
# 57       0.000961      0.000249         0.002705        0.000192
# 58       0.000920      0.000167         0.002985        0.000398
# 59       0.001356      0.001087         0.003464        0.000923
# 60       0.002196      0.001708         0.004167        0.000604
# 61       0.001466      0.000428         0.003882        0.000619
# 62       0.000807      0.000113         0.002901        0.000253
# 63       0.000907      0.000209         0.002890        0.000185
# 64       0.000858      0.000112         0.002780        0.000249
# 65       0.000921      0.000202         0.002691        0.000085
# 66       0.000827      0.000202         0.002795        0.000235
#
#     param_n_neighbors                params  split0_test_score  \
# 0                   1    {'n_neighbors': 1}     -109655.806526
# 1                   4    {'n_neighbors': 4}      -84174.862641
# 2                   7    {'n_neighbors': 7}      -82345.022650
# 3                  10   {'n_neighbors': 10}      -79985.458885
# 4                  13   {'n_neighbors': 13}      -77430.800364
# 5                  16   {'n_neighbors': 16}      -76694.888762
# 6                  19   {'n_neighbors': 19}      -76433.653070
# 7                  22   {'n_neighbors': 22}      -76193.344530
# 8                  25   {'n_neighbors': 25}      -76418.878174
# 9                  28   {'n_neighbors': 28}      -75907.224288
# 10                 31   {'n_neighbors': 31}      -77062.839864
# 11                 34   {'n_neighbors': 34}      -77449.190594
# 12                 37   {'n_neighbors': 37}      -77177.447738
# 13                 40   {'n_neighbors': 40}      -77551.369282
# 14                 43   {'n_neighbors': 43}      -77873.107956
# 15                 46   {'n_neighbors': 46}      -77635.440911
# 16                 49   {'n_neighbors': 49}      -77587.496613
# 17                 52   {'n_neighbors': 52}      -77480.794799
# 18                 55   {'n_neighbors': 55}      -77192.573035
# 19                 58   {'n_neighbors': 58}      -77358.856384
# 20                 61   {'n_neighbors': 61}      -77438.674904
# 21                 64   {'n_neighbors': 64}      -77870.860121
# 22                 67   {'n_neighbors': 67}      -78276.425210
# 23                 70   {'n_neighbors': 70}      -78882.318222
# 24                 73   {'n_neighbors': 73}      -79146.108581
# 25                 76   {'n_neighbors': 76}      -79546.251794
# 26                 79   {'n_neighbors': 79}      -79763.970542
# 27                 82   {'n_neighbors': 82}      -79686.317329
# 28                 85   {'n_neighbors': 85}      -80164.271796
# 29                 88   {'n_neighbors': 88}      -80244.043098
# 30                 91   {'n_neighbors': 91}      -80509.445273
# 31                 94   {'n_neighbors': 94}      -80158.003426
# 32                 97   {'n_neighbors': 97}      -80488.634292
# 33                100  {'n_neighbors': 100}      -80794.579370
# 34                103  {'n_neighbors': 103}      -81044.317121
# 35                106  {'n_neighbors': 106}      -81279.274576
# 36                109  {'n_neighbors': 109}      -81513.890899
# 37                112  {'n_neighbors': 112}      -81851.628918
# 38                115  {'n_neighbors': 115}      -81999.400098
# 39                118  {'n_neighbors': 118}      -82574.532270
# 40                121  {'n_neighbors': 121}      -82843.363834
# 41                124  {'n_neighbors': 124}      -83170.204199
# 42                127  {'n_neighbors': 127}      -83633.126523
# 43                130  {'n_neighbors': 130}      -83792.942198
# 44                133  {'n_neighbors': 133}      -83966.325863
# 45                136  {'n_neighbors': 136}      -84278.015111
# 46                139  {'n_neighbors': 139}      -84699.644798
# 47                142  {'n_neighbors': 142}      -84931.753721
# 48                145  {'n_neighbors': 145}      -85457.514330
# 49                148  {'n_neighbors': 148}      -85568.215563
# 50                151  {'n_neighbors': 151}      -85813.630768
# 51                154  {'n_neighbors': 154}      -86026.112182
# 52                157  {'n_neighbors': 157}      -86067.116613
# 53                160  {'n_neighbors': 160}      -86520.457882
# 54                163  {'n_neighbors': 163}      -87080.271040
# 55                166  {'n_neighbors': 166}      -87501.745546
# 56                169  {'n_neighbors': 169}      -87940.412255
# 57                172  {'n_neighbors': 172}      -88377.454206
# 58                175  {'n_neighbors': 175}      -88696.027223
# 59                178  {'n_neighbors': 178}      -88549.172203
# 60                181  {'n_neighbors': 181}      -88658.378242
# 61                184  {'n_neighbors': 184}      -89013.183280
# 62                187  {'n_neighbors': 187}      -89404.102502
# 63                190  {'n_neighbors': 190}      -89863.315392
# 64                193  {'n_neighbors': 193}      -90257.326655
# 65                196  {'n_neighbors': 196}      -90618.127253
# 66                199  {'n_neighbors': 199}      -90874.655005
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0      -120595.130103     -112297.705616     -120818.303875
# 1       -96956.242253      -99795.018109      -90744.186040
# 2       -94442.362234      -97121.482754      -87597.243261
# 3       -94722.834905      -95690.903059      -84342.146484
# 4       -92812.039395      -96240.816885      -84657.354893
# 5       -93161.417884      -97831.534297      -84036.827132
# 6       -92712.500840      -97385.573363      -82625.375952
# 7       -92163.118393      -98571.117671      -83391.706835
# 8       -93399.616892      -98536.929259      -83448.028427
# 9       -93551.873437      -99640.124290      -84043.091505
# 10      -93792.730579      -99885.815075      -84541.218598
# 11      -93548.521418      -99851.413654      -84254.106503
# 12      -93322.645774      -99895.010776      -84469.525884
# 13      -94290.794082     -100002.599903      -84935.037639
# 14      -94380.911465      -99870.618868      -85392.500646
# 15      -94604.322212     -100554.520530      -85794.551165
# 16      -94950.830674     -100777.514625      -86204.323498
# 17      -94736.700430     -101397.670920      -85986.925262
# 18      -95174.334724     -101523.436538      -86507.015799
# 19      -95462.192591     -101770.901861      -86890.641349
# 20      -95242.224662     -101643.853682      -87001.792713
# 21      -95363.237796     -101751.796272      -87361.526381
# 22      -95507.840465     -101776.512253      -87775.997993
# 23      -95614.094488     -102206.572498      -88067.622739
# 24      -95621.521197     -102267.365639      -88539.546917
# 25      -95825.394425     -102583.659679      -88720.122063
# 26      -96174.434642     -103003.039245      -89449.590224
# 27      -96670.433655     -103613.592465      -89834.119384
# 28      -97100.503177     -103800.034599      -89996.931089
# 29      -97276.820068     -104156.482265      -89639.569273
# 30      -97282.027338     -104256.143914      -89589.219214
# 31      -97362.460682     -104135.232524      -89571.428934
# 32      -97711.007547     -104322.012606      -90115.884811
# 33      -97895.778291     -104077.989063      -90710.491836
# 34      -98051.785011     -104544.170767      -91206.727130
# 35      -98309.486949     -105024.015506      -91635.540843
# 36      -98310.881626     -104877.198873      -91681.762613
# 37      -98560.178956     -105229.716249      -92285.396671
# 38      -98829.687919     -105356.650142      -92851.412966
# 39      -99178.867939     -105794.094272      -92857.198553
# 40      -99381.252529     -105938.941153      -93094.084107
# 41      -99635.807483     -106203.049496      -93306.538049
# 42      -99738.208144     -106405.393176      -93440.686754
# 43      -99674.344089     -106509.918012      -93616.396629
# 44      -99901.901679     -106786.378901      -93936.190572
# 45     -100017.078225     -106916.230912      -94154.059274
# 46     -100195.219870     -107148.471614      -94428.207514
# 47     -100710.067055     -107192.161634      -94855.707941
# 48     -100967.175908     -107603.959433      -95203.097863
# 49     -101256.999302     -107865.769464      -95744.177813
# 50     -101266.006145     -108049.238645      -95788.477157
# 51     -101594.121703     -108080.509891      -95860.940537
# 52     -101827.427381     -108389.415374      -95983.033124
# 53     -101984.261201     -108643.030959      -96200.610428
# 54     -102300.005296     -108855.088908      -96442.934489
# 55     -102619.720726     -109205.508635      -96655.890602
# 56     -102785.011275     -109572.753187      -96985.371624
# 57     -103063.959039     -109712.956781      -97363.267320
# 58     -103265.059618     -109705.516676      -97773.705057
# 59     -103123.767264     -110090.471964      -98228.560887
# 60     -103298.797667     -110241.381804      -97638.200202
# 61     -103560.378834     -110561.211151      -97909.459799
# 62     -103889.117510     -110881.591477      -98253.628778
# 63     -104222.245365     -111093.057167      -98689.116523
# 64     -104471.730296     -111383.626131      -99098.910125
# 65     -104552.352275     -111682.970126      -99529.902613
# 66     -104748.785052     -111903.021513      -99830.397996
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0      -112115.342058   -115096.457636     4675.375295               67
# 1       -96708.754264    -93675.812662     5590.476086               49
# 2       -90165.220710    -90334.266322     5182.482900               31
# 3       -88185.414673    -88585.351601     6004.672460               20
# 4       -85242.671132    -87276.736534     6617.179998                6
# 5       -83282.882249    -87001.510065     7537.610624                4
# 6       -83950.474751    -86621.515595     7481.459416                1
# 7       -82901.393279    -86644.136142     7829.655412                2
# 8       -81730.096687    -86706.709888     8074.332910                3
# 9       -82046.129273    -87037.688559     8473.800818                5
# 10      -82432.369813    -87542.994786     8202.038835                8
# 11      -83100.722958    -87640.791026     7999.389387                9
# 12      -82533.536384    -87479.633311     8098.667068                7
# 13      -81909.866585    -87737.933498     8233.476830               11
# 14      -80940.120922    -87691.451971     8250.412135               10
# 15      -80252.365840    -87768.240131     8640.352067               12
# 16      -80104.243033    -87924.881689     8781.097565               13
# 17      -80135.551140    -87947.528510     8960.163573               14
# 18      -79905.430762    -88060.558171     9153.006158               15
# 19      -79692.105417    -88234.939520     9257.772950               17
# 20      -79814.598218    -88228.228836     9142.023050               16
# 21      -79518.111163    -88373.106346     9138.738330               18
# 22      -79412.041789    -88549.763542     9088.452766               19
# 23      -79181.370048    -88790.395599     9138.735570               21
# 24      -79029.433828    -88920.795233     9127.535811               22
# 25      -78844.670193    -89104.019631     9204.674130               23
# 26      -78653.274592    -89408.861849     9373.183863               24
# 27      -78638.697944    -89688.632156     9641.769405               25
# 28      -78500.935361    -89912.535205     9693.192417               26
# 29      -78353.833460    -89934.149633     9841.526503               27
# 30      -78403.945911    -90008.156330     9807.885288               29
# 31      -78449.812851    -89935.387684     9843.222490               28
# 32      -78490.076943    -90225.523240     9872.013113               30
# 33      -78238.759859    -90343.519684     9833.762243               32
# 34      -78143.854620    -90598.170930     9967.986079               33
# 35      -78064.546232    -90862.572821    10121.556781               35
# 36      -77872.681174    -90851.283037    10086.551648               34
# 37      -77802.915960    -91145.967351    10188.646262               36
# 38      -77737.651602    -91354.960545    10267.578535               37
# 39      -77662.575859    -91613.453779    10355.694608               38
# 40      -77656.843913    -91782.897107    10385.648112               39
# 41      -77754.374336    -92013.994713    10417.690509               40
# 42      -77755.601227    -92194.603165    10413.346363               41
# 43      -77835.869430    -92285.894072    10388.606561               42
# 44      -77830.591815    -92484.277766    10478.218444               43
# 45      -77891.672099    -92651.411124    10468.617328               44
# 46      -77839.054484    -92862.119656    10513.280413               45
# 47      -77763.838578    -93090.705786    10597.191260               46
# 48      -77685.148044    -93383.379116    10698.635857               47
# 49      -77785.467687    -93644.125966    10782.750792               48
# 50      -77825.118808    -93748.494304    10786.118389               50
# 51      -77892.428892    -93890.822641    10792.327630               51
# 52      -77973.205876    -94048.039673    10881.484680               52
# 53      -78023.476157    -94274.367325    10897.944266               53
# 54      -78055.465274    -94546.753001    10919.229145               54
# 55      -78111.599540    -94818.893010    10989.781476               55
# 56      -78182.151965    -95093.140061    11041.264898               56
# 57      -78198.416300    -95343.210729    11069.290173               57
# 58      -78192.775270    -95526.616769    11073.329407               58
# 59      -78133.974109    -95625.189285    11209.489234               60
# 60      -78216.287369    -95610.609057    11208.700383               59
# 61      -78394.357302    -95887.718073    11238.731793               61
# 62      -78552.980467    -96196.284147    11282.645963               62
# 63      -78637.308937    -96501.008677    11318.161791               63
# 64      -78655.460986    -96773.410839    11391.662919               64
# 65      -78741.616470    -97024.993747    11429.101358               65
# 66      -78908.505642    -97253.073041    11442.522995               66

# %%
results["mean_test_score"] = results["mean_test_score"].abs()

# %%
#Create the plot
plt.figure(figsize=(10, 6))

# Plot mean test scores with error bars
plt.plot(results['param_n_neighbors'], results['mean_test_score'], '-o', color='blue')

# Add labels and legend
plt.xlabel('Number of Neighbors')
plt.ylabel('RMSPE')
plt.title('K-Nearest Neighbors Regression Performance')
plt.tight_layout()
plt.show()

# %%
sacr_gridsearch.best_params_
# Out:
# {'n_neighbors': 19}

# %%
#make predictions on the test set
sacramento_test["predicted"] = sacr_gridsearch.predict(sacramento_test[["sq__ft"]])

# %%
#calculate RMSPE
mean_squared_error(
    y_true = sacramento_test["price"],
    y_pred = sacramento_test["predicted"]
)**(1/2)
# Out:
# 74240.70943389146

# %%
#calculate r2
r2_score(
  y_true = sacramento_test["price"],
  y_pred= sacramento_test["predicted"]  
)
# Out:
# 0.49526130381694955

# %%
# Generate a range of house sizes for prediction
sizes = np.linspace(sacramento["sq__ft"].min(), sacramento["sq__ft"].max(), 100).reshape(-1, 1)

# Predict house prices for these sizes using the best model from GridSearchCV
predicted_prices = sacr_gridsearch.predict(sizes)

# Plot the original data
plt.scatter(sacramento["sq__ft"], sacramento["price"], label="Actual Prices")

# Plot the model predictions as a line
plt.plot(sizes, predicted_prices, color='red', label="Model Predictions")

# Add labels and legend
plt.xlabel("House size (square feet)")
plt.ylabel("Price (USD)")
plt.title("Scatter Plot of House Size vs Price with Model Predictions")
plt.legend()
plt.show()
# Out:
# /Users/juliagallucci/Desktop/CI:TA Positions/DSI Linear regression, classification, and resampling CI/LCR/lcr-env/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
